# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %%
dataset = pd.read_csv('interns.csv')
dataset
# Out:
#    aggrigate  interview_score  salary  Java  Python  C  C++  ML  AI  \
# 0        5.0                7    5000     0       0  1    0   1   1
# 1        6.0                9   10000     0       0  1    0   0   0
# 2        6.6                6   15000     1       0  0    0   0   0
# 3        7.0                7   15500     0       1  0    0   1   0
# 4        7.0                8   30000     0       1  1    1   1   0
# 5        9.0                6   19000     0       1  1    0   1   0
# 6        7.1               10   20000     0       1  0    1   0   0
# 7        NaN                7   30889     1       1  0    1   1   0
# 8        7.3                8   30033     1       1  1    0   1   0
#
#    DataScience
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0
# 5            1
# 6            1
# 7            1
# 8            0

# %%
dataset['aggrigate'].fillna(dataset['aggrigate'].mean(), inplace=True)
X = dataset.drop(['salary'],axis=1)
X
# Out:
#    aggrigate  interview_score  Java  Python  C  C++  ML  AI  DataScience
# 0      5.000                7     0       0  1    0   1   1            1
# 1      6.000                9     0       0  1    0   0   0            0
# 2      6.600                6     1       0  0    0   0   0            0
# 3      7.000                7     0       1  0    0   1   0            0
# 4      7.000                8     0       1  1    1   1   0            0
# 5      9.000                6     0       1  1    0   1   0            1
# 6      7.100               10     0       1  0    1   0   0            1
# 7      6.875                7     1       1  0    1   1   0            1
# 8      7.300                8     1       1  1    0   1   0            0

# %%
y = dataset['salary']
y
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    15500
# 4    30000
# 5    19000
# 6    20000
# 7    30889
# 8    30033
# Name: salary, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
X=X.drop(["DataScience","AI","ML"],axis=1) 
X
# Out:
#    aggrigate  interview_score  Java  Python  C  C++
# 0      5.000                7     0       0  1    0
# 1      6.000                9     0       0  1    0
# 2      6.600                6     1       0  0    0
# 3      7.000                7     0       1  0    0
# 4      7.000                8     0       1  1    1
# 5      9.000                6     0       1  1    0
# 6      7.100               10     0       1  0    1
# 7      6.875                7     1       1  0    1
# 8      7.300                8     1       1  1    0

# %%
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
regressor.score(X_test,y_test)
# Out:
# 0.975532896748631

# %%
regressor.score(X_train,y_train)
# Out:
# 0.9489512743437261

# %%
pickle.dump(regressor, open('model.pickle','wb'))

# %%
model = pickle.load(open('model.pickle','rb'))

# %%
X
# Out:
#    aggrigate  interview_score  Java  Python  C  C++
# 0      5.000                7     0       0  1    0
# 1      6.000                9     0       0  1    0
# 2      6.600                6     1       0  0    0
# 3      7.000                7     0       1  0    0
# 4      7.000                8     0       1  1    1
# 5      9.000                6     0       1  1    0
# 6      7.100               10     0       1  0    1
# 7      6.875                7     1       1  0    1
# 8      7.300                8     1       1  1    0

# %%
model.predict([[8,9,1,1,1,1]])
# Out:
# array([38576.75187354])

# %%
model.predict([[7,9,0,1,1,0]])
# Out:
# array([19524.56897088])
